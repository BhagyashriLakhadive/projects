# %% [markdown]
# <a href="https://colab.research.google.com/github/BhagyashriLakhadive/projects/blob/main/image_preprocessing_by_bhagyashri_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# if you want to make a neural network from scratch and need to have a bias we need to a equation -
# y = 3x1 + 4x2 + 7
# x1 = 3
# x2 = 2
# y = 24

# %%
# if we dont have opencv installed we can install it by using
# pip install opencv-python
! pip show opencv-python
# Out:
# Name: opencv-python
# Version: 4.8.0.76
# Summary: Wrapper package for OpenCV python bindings.
# Home-page: https://github.com/opencv/opencv-python
# Author:
# Author-email:
# License: Apache 2.0
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: numpy, numpy, numpy, numpy
# Required-by: dopamine-rl, imgaug

# %%
import cv2

# %%
! wget https://images.designtrends.com/wp-content/uploads/2016/04/02133843/Beautiful-Horizon-Background.jpg
# Out:
# --2023-11-01 15:44:19--  https://images.designtrends.com/wp-content/uploads/2016/04/02133843/Beautiful-Horizon-Background.jpg
# Resolving images.designtrends.com (images.designtrends.com)... 104.18.17.180, 104.18.16.180, 2606:4700::6812:10b4, ...
# Connecting to images.designtrends.com (images.designtrends.com)|104.18.17.180|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 744960 (728K) [image/jpg]
# Saving to: ‘Beautiful-Horizon-Background.jpg’
#
# Beautiful-Horizon-B 100%[===================>] 727.50K  --.-KB/s    in 0.06s
#
# 2023-11-01 15:44:19 (12.5 MB/s) - ‘Beautiful-Horizon-Background.jpg’ saved [744960/744960]

# %%
image = cv2.imread('Beautiful-Horizon-Background.jpg')

# %%
type(image)
# Out:
# numpy.ndarray

# %%
image
# Out:
# array([[[157,  11,  16],
#         [183,  37,  42],
#         [189,  43,  48],
#         ...,
#         [ 52,  10,  28],
#         [ 52,  10,  28],
#         [ 51,   9,  27]],
#
#        [[176,  30,  35],
#         [189,  43,  48],
#         [192,  46,  51],
#         ...,
#         [ 51,   9,  27],
#         [ 51,   9,  27],
#         [ 51,   9,  27]],
#
#        [[210,  64,  69],
#         [214,  68,  73],
#         [221,  73,  79],
#         ...,
#         [ 50,   8,  26],
#         [ 50,   8,  26],
#         [ 50,   8,  26]],
#
#        ...,
#
#        [[150,  73,  57],
#         [173, 100,  92],
#         [130,  61,  71],
#         ...,
#         [ 34,  79, 214],
#         [ 25,  66, 205],
#         [ 16,  57, 196]],
#
#        [[124,  64,  42],
#         [151,  91,  79],
#         [145,  89,  94],
#         ...,
#         [ 39,  85, 227],
#         [ 22,  66, 213],
#         [  6,  49, 198]],
#
#        [[157, 106,  80],
#         [153, 102,  86],
#         [169, 119, 121],
# ...

# %%
image.shape
# Out:
# (1600, 2560, 3)

# %%
image.min()
# Out:
# 0

# %%
image.max()
# Out:
# 255

# %%
import matplotlib.pyplot as plt
image_bgr = image.copy()

# %%
plt.imshow(image)

# %%
# It looks like the loaded image has replaced red gradients with blue .
# The issues is with OPENCV, opencv read the image in BGR format by deafult!
image_rgb = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(image_rgb)

# %%
plt.subplot(1,2,1)
plt.imshow(image_bgr)
plt.subplot(1,2,2)
plt.imshow(image_rgb)

# %%
image2 = cv2.cvtColor(cv2.imread("RGB-color-model.jpg"), cv2.COLOR_BGR2RGB)

# %%
plt.figure(figsize= (5,3))
plt.imshow(image2)

# %%
plt.figure(figsize= (5,3))

plt.imshow(image2[:,:,0], cmap = 'gray')

# %%
plt.figure(figsize= (5,3))
plt.imshow(image2[:,:,1], cmap = 'gray')

# %%
plt.figure(figsize= (5,3))
plt.imshow(image2[:,:,2], cmap = 'gray')

# %%
# resize and cropping of image
image2.shape
# Out:
# (720, 720, 3)

# %%
image2_resize = cv2.resize(image2, (100,100))

# %%
image2_resize.shape
# Out:
# (100, 100, 3)

# %%
plt.figure(figsize= (5,3))
plt.imshow(image2_resize)

# %%
image2_resize[:,:,0]
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
import numpy as np
import sys
np.set_printoptions(threshold=sys.maxsize)

# %%
image2_resize[:,:,0]

# %%
image3 = np.zeros((50,50,3))

# %%
plt.imshow(image3)

# %%
image3[:,:,:] = 255

# %%
plt.imshow(image3)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
image3[:, :, :] = 0

image3[:10, :10, 0] = 255
image3[:10, 10:20, 1] = 50
image3[:10, 20:30, 2] = 150
image3[:10,30:40,2] = 255
image3[20:30, 20:30, 1] = 255

# image3[10:20, :10, 0] = 50
plt.imshow(image3)
plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
image3[:,:,:] = 0

image3[:10,:10, 0] = 255
image3[:10,10:20,1] = 255
image3[:10,20:30,2] = 255
plt.imshow(image3)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
image3[20:30, 20:30, 0] = 255
image3[20:30, 20:30, 1] = 255
plt.imshow(image3)
plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
image3[20:30, 20:30, 0] = 255
image3[20:30, 20:30, 1] = 255
plt.imshow(image3)
plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
image3[20:30, :10, 0] = 255
image3[20:30, :10, 1] = 255
plt.imshow(image3)
plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
